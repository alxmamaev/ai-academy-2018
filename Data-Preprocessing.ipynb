# %% [markdown]
# # DOTA SCIENCE - SBERBANK CONTEST

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score

from lightgbm.sklearn import LGBMClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

from sklearn.linear_model import LogisticRegression, Lasso
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

import json
from annoy import AnnoyIndex

from sklearn.preprocessing import MinMaxScaler, LabelEncoder, PolynomialFeatures
from tqdm import tqdm_notebook, tqdm, tqdm_pandas
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
tqdm_pandas(tqdm())
# Out:
# 0it [00:00, ?it/s]
# TqdmDeprecationWarning: Please use `tqdm.pandas(...)` instead of `tqdm_pandas(tqdm(...))`.

# %% [markdown]
# # Load data

# %%
fights_train = pd.read_csv("data_final/train_features.csv")
fights_test = pd.read_csv("data_final/test_features.csv")

fights_train["is_train"] = True
fights_test["is_train"] = False

fights = pd.concat([fights_train, fights_test])

fights.index = np.arange(0, fights.shape[0])
fights["fight_id"] = np.arange(0, fights.shape[0])
# fights = fights.set_index("fight_id")


target = pd.read_csv("data_final/train_targets.csv")
heroes = pd.read_json("dictionaries/heroes.json").transpose().set_index("id")
items = pd.read_json("dictionaries/items.json").transpose().set_index("id")

hero2id = dict(zip(heroes.name, heroes.index))

CATEFORICAL_FEATURES = []

# %%
heroes.head()
# Out:
#     agi_gain attack_range attack_rate attack_type base_agi base_armor  \
# id
# 1        2.8          150        1.45       Melee       22         -1
# 10       3.7          350         1.5      Ranged       24         -2
# 100      2.1          150         1.7       Melee       23          0
# 101      0.8          600         1.7      Ranged       13         -2
# 102      1.5          150         1.7       Melee       17         -1
#
#     base_attack_max base_attack_min base_health base_health_regen    ...     \
# id                                                                   ...
# 1                31              27         200               1.5    ...
# 10               18               9         200               1.5    ...
# 100              31              27         200               1.5    ...
# 101              22              12         200               1.5    ...
# 102              42              32         200               1.5    ...
#
#     int_gain legs localized_name move_speed                         name  \
# id
# 1        1.8    2      Anti-Mage        310       npc_dota_hero_antimage
# 10       1.1    0      Morphling        280      npc_dota_hero_morphling
# 100      1.7    2           Tusk        300           npc_dota_hero_tusk
# 101      3.6    2  Skywrath Mage        330  npc_dota_hero_skywrath_mage
# 102        2    2        Abaddon        310        npc_dota_hero_abaddon
#
#     primary_attr projectile_speed                                      roles  \
# id
# 1            agi                0                     [Carry, Escape, Nuker]
# 10           agi             1300  [Carry, Escape, Durable, Nuker, Disabler]
# 100          str              900               [Initiator, Disabler, Nuker]
# 101          int             1000                 [Support, Nuker, Disabler]
# 102          str              900                  [Support, Carry, Durable]
#
#     str_gain turn_rate
# id
# 1        1.3       0.5
# 10       2.3       0.6
# 100      2.6       0.7
# 101      1.8       0.5
# 102      2.6       0.5
#
# [5 rows x 28 columns]

# %%
fights_train.head()
# Out:
#                       match_id_hash  game_time  game_mode  lobby_type  \
# 0  a400b8f29dece5f4d266f49f1ae2e98a        155         22           7
# 1  b9c57c450ce74a2af79c9ce96fac144d        658          4           0
# 2  6db558535151ea18ca70a6892197db41         21         23           0
# 3  46a0ddce8f7ed2a8d9bd5edcbb925682        576         22           7
# 4  b1b35ff97723d9b7ade1c9c3cf48f770        453         22           7
#
#    objectives_len  chat_len  r1_hero_id  r1_kills  r1_deaths  r1_assists  \
# 0               1        11          11         0          0           0
# 1               3        10          15         7          2           0
# 2               0         0         101         0          0           0
# 3               1         4          14         1          0           3
# 4               1         3          42         0          1           1
#
#      ...     d5_creeps_stacked  d5_camps_stacked  d5_rune_pickups  \
# 0    ...                     0                 0                0
# 1    ...                     0                 0                0
# 2    ...                     0                 0                0
# 3    ...                     3                 1                3
# 4    ...                     2                 1                2
#
#    d5_firstblood_claimed  d5_teamfight_participation  d5_towers_killed  \
# 0                      0                        0.00                 0
# 1                      0                        0.00                 0
# 2                      0                        0.00                 0
# 3                      0                        0.00                 0
# 4                      0                        0.25                 0
#
#    d5_roshans_killed  d5_obs_placed  d5_sen_placed  is_train
# 0                  0              0              0      True
# 1                  0              0              0      True
# 2                  0              0              0      True
# 3                  0              2              0      True
# 4                  0              0              0      True
#
# [5 rows x 247 columns]

# %%
fights.columns.tolist()
# Out:
# ['match_id_hash',
#  'game_time',
#  'game_mode',
#  'lobby_type',
#  'objectives_len',
#  'chat_len',
#  'r1_hero_id',
#  'r1_kills',
#  'r1_deaths',
#  'r1_assists',
#  'r1_denies',
#  'r1_gold',
#  'r1_lh',
#  'r1_xp',
#  'r1_health',
#  'r1_max_health',
#  'r1_max_mana',
#  'r1_level',
#  'r1_x',
#  'r1_y',
#  'r1_stuns',
#  'r1_creeps_stacked',
#  'r1_camps_stacked',
#  'r1_rune_pickups',
#  'r1_firstblood_claimed',
#  'r1_teamfight_participation',
#  'r1_towers_killed',
#  'r1_roshans_killed',
#  'r1_obs_placed',
#  'r1_sen_placed',
#  'r2_hero_id',
#  'r2_kills',
#  'r2_deaths',
#  'r2_assists',
#  'r2_denies',
#  'r2_gold',
#  'r2_lh',
#  'r2_xp',
#  'r2_health',
#  'r2_max_health',
#  'r2_max_mana',
#  'r2_level',
#  'r2_x',
#  'r2_y',
#  'r2_stuns',
#  'r2_creeps_stacked',
#  'r2_camps_stacked',
#  'r2_rune_pickups',
#  'r2_firstblood_claimed',
#  'r2_teamfight_participation',
#  'r2_towers_killed',
#  'r2_roshans_killed',
#  'r2_obs_placed',
#  'r2_sen_placed',
#  'r3_hero_id',
#  'r3_kills',
#  'r3_deaths',
#  'r3_assists',
#  'r3_denies',
#  'r3_gold',
#  'r3_lh',
#  'r3_xp',
#  'r3_health',
#  'r3_max_health',
#  'r3_max_mana',
#  'r3_level',
#  'r3_x',
#  'r3_y',
#  'r3_stuns',
#  'r3_creeps_stacked',
#  'r3_camps_stacked',
#  'r3_rune_pickups',
#  'r3_firstblood_claimed',
#  'r3_teamfight_participation',
#  'r3_towers_killed',
#  'r3_roshans_killed',
#  'r3_obs_placed',
#  'r3_sen_placed',
#  'r4_hero_id',
#  'r4_kills',
#  'r4_deaths',
#  'r4_assists',
#  'r4_denies',
#  'r4_gold',
#  'r4_lh',
#  'r4_xp',
#  'r4_health',
#  'r4_max_health',
#  'r4_max_mana',
#  'r4_level',
#  'r4_x',
#  'r4_y',
#  'r4_stuns',
#  'r4_creeps_stacked',
#  'r4_camps_stacked',
#  'r4_rune_pickups',
#  'r4_firstblood_claimed',
#  'r4_teamfight_participation',
#  'r4_towers_killed',
#  'r4_roshans_killed',
#  'r4_obs_placed',
#  'r4_sen_placed',
#  'r5_hero_id',
#  'r5_kills',
#  'r5_deaths',
#  'r5_assists',
#  'r5_denies',
#  'r5_gold',
#  'r5_lh',
#  'r5_xp',
#  'r5_health',
#  'r5_max_health',
#  'r5_max_mana',
#  'r5_level',
#  'r5_x',
#  'r5_y',
#  'r5_stuns',
#  'r5_creeps_stacked',
#  'r5_camps_stacked',
#  'r5_rune_pickups',
#  'r5_firstblood_claimed',
#  'r5_teamfight_participation',
#  'r5_towers_killed',
#  'r5_roshans_killed',
#  'r5_obs_placed',
#  'r5_sen_placed',
#  'd1_hero_id',
#  'd1_kills',
#  'd1_deaths',
#  'd1_assists',
#  'd1_denies',
#  'd1_gold',
#  'd1_lh',
#  'd1_xp',
#  'd1_health',
#  'd1_max_health',
#  'd1_max_mana',
#  'd1_level',
#  'd1_x',
#  'd1_y',
#  'd1_stuns',
#  'd1_creeps_stacked',
#  'd1_camps_stacked',
#  'd1_rune_pickups',
#  'd1_firstblood_claimed',
#  'd1_teamfight_participation',
#  'd1_towers_killed',
#  'd1_roshans_killed',
#  'd1_obs_placed',
#  'd1_sen_placed',
#  'd2_hero_id',
#  'd2_kills',
#  'd2_deaths',
#  'd2_assists',
#  'd2_denies',
#  'd2_gold',
#  'd2_lh',
#  'd2_xp',
#  'd2_health',
#  'd2_max_health',
#  'd2_max_mana',
#  'd2_level',
#  'd2_x',
#  'd2_y',
#  'd2_stuns',
#  'd2_creeps_stacked',
#  'd2_camps_stacked',
#  'd2_rune_pickups',
#  'd2_firstblood_claimed',
#  'd2_teamfight_participation',
#  'd2_towers_killed',
#  'd2_roshans_killed',
#  'd2_obs_placed',
#  'd2_sen_placed',
#  'd3_hero_id',
#  'd3_kills',
#  'd3_deaths',
#  'd3_assists',
#  'd3_denies',
#  'd3_gold',
#  'd3_lh',
#  'd3_xp',
#  'd3_health',
#  'd3_max_health',
#  'd3_max_mana',
#  'd3_level',
#  'd3_x',
#  'd3_y',
#  'd3_stuns',
#  'd3_creeps_stacked',
#  'd3_camps_stacked',
#  'd3_rune_pickups',
#  'd3_firstblood_claimed',
#  'd3_teamfight_participation',
#  'd3_towers_killed',
#  'd3_roshans_killed',
#  'd3_obs_placed',
#  'd3_sen_placed',
#  'd4_hero_id',
#  'd4_kills',
#  'd4_deaths',
#  'd4_assists',
#  'd4_denies',
#  'd4_gold',
#  'd4_lh',
#  'd4_xp',
#  'd4_health',
#  'd4_max_health',
#  'd4_max_mana',
#  'd4_level',
#  'd4_x',
#  'd4_y',
#  'd4_stuns',
#  'd4_creeps_stacked',
#  'd4_camps_stacked',
#  'd4_rune_pickups',
#  'd4_firstblood_claimed',
#  'd4_teamfight_participation',
#  'd4_towers_killed',
#  'd4_roshans_killed',
#  'd4_obs_placed',
#  'd4_sen_placed',
#  'd5_hero_id',
#  'd5_kills',
#  'd5_deaths',
#  'd5_assists',
#  'd5_denies',
#  'd5_gold',
#  'd5_lh',
#  'd5_xp',
#  'd5_health',
#  'd5_max_health',
#  'd5_max_mana',
#  'd5_level',
#  'd5_x',
#  'd5_y',
#  'd5_stuns',
#  'd5_creeps_stacked',
#  'd5_camps_stacked',
#  'd5_rune_pickups',
#  'd5_firstblood_claimed',
#  'd5_teamfight_participation',
#  'd5_towers_killed',
#  'd5_roshans_killed',
#  'd5_obs_placed',
#  'd5_sen_placed',
#  'is_train',
#  'fight_id']

# %%
heroes.columns
# Out:
# Index(['agi_gain', 'attack_range', 'attack_rate', 'attack_type', 'base_agi',
#        'base_armor', 'base_attack_max', 'base_attack_min', 'base_health',
#        'base_health_regen', 'base_int', 'base_mana', 'base_mana_regen',
#        'base_mr', 'base_str', 'cm_enabled', 'icon', 'img', 'int_gain', 'legs',
#        'localized_name', 'move_speed', 'name', 'primary_attr',
#        'projectile_speed', 'roles', 'str_gain', 'turn_rate'],
#       dtype='object')

# %% [markdown]
# # Preprocess data

# %%
for team in ["r", "d"]:
    for i in range(1,6):
        fights["%s%s_hero_id" % (team, i)] = fights["%s%s_hero_id" % (team, i)].fillna(1).astype("int32")

# %% [markdown]
# ---
# # Process heroes

# %% [markdown]
# *Add hero winrate from herostat*

# %%
import requests

hero_id_2_winrate = {}
for hero in requests.get('https://api.opendota.com/api/heroStats').json():
    tmp = 0
    for i in range(1, 8):
        tmp += hero['{}_win'.format(i)] / hero['{}_pick'.format(i)]
    hero_id_2_winrate[hero['id']] = tmp / 7

    
winrate = [hero_id_2_winrate[hero_id] for hero_id in heroes.index]
heroes["winrate"] = winrate

# %% [markdown]
# *Delete usles features*

# %%
heroes = heroes.drop(["roles", "localized_name", "icon", "img", "name", "cm_enabled"], axis=1)

# %% [markdown]
# *Prepare categorical features*

# %%
heroes["attack_type"] = LabelEncoder().fit_transform(heroes["attack_type"])
heroes["primary_attr"] = LabelEncoder().fit_transform(heroes["primary_attr"])

hero_categorical_features = ["attack_type", "primary_attr"]

# %% [markdown]
# *Add features from hero to player*

# %%
for feature in heroes.columns:
    for i in range(1, 6):
        for team in ["r", "d"]:            
            if feature in hero_categorical_features:
                CATEFORICAL_FEATURES.append("%s%s_hero_%s" % (team, i, feature))
            
            players_heroes = fights["%s%s_hero_id" % (team, i)]
            fights["%s%s_hero_%s" % (team, i, feature)] = heroes.loc[players_heroes.get_values()][feature].get_values()

# %%
fights.head()
# Out:
#                       match_id_hash  game_time  game_mode  lobby_type  \
# 0  a400b8f29dece5f4d266f49f1ae2e98a        155         22           7
# 1  b9c57c450ce74a2af79c9ce96fac144d        658          4           0
# 2  6db558535151ea18ca70a6892197db41         21         23           0
# 3  46a0ddce8f7ed2a8d9bd5edcbb925682        576         22           7
# 4  b1b35ff97723d9b7ade1c9c3cf48f770        453         22           7
#
#    objectives_len  chat_len  r1_hero_id  r1_kills  r1_deaths  r1_assists  \
# 0               1        11          11         0          0           0
# 1               3        10          15         7          2           0
# 2               0         0         101         0          0           0
# 3               1         4          14         1          0           3
# 4               1         3          42         0          1           1
#
#         ...         r1_hero_winrate  d1_hero_winrate  r2_hero_winrate  \
# 0       ...                0.475748         0.516962         0.513125
# 1       ...                0.470987         0.484695         0.535258
# 2       ...                0.505830         0.495689         0.519760
# 3       ...                0.513150         0.495689         0.521984
# 4       ...                0.543573         0.486286         0.500539
#
#    d2_hero_winrate  r3_hero_winrate  d3_hero_winrate  r4_hero_winrate  \
# 0         0.482539         0.513150         0.528186         0.507785
# 1         0.513150         0.521155         0.479300         0.475609
# 2         0.566072         0.502387         0.506220         0.516962
# 3         0.450398         0.505830         0.513278         0.488747
# 4         0.563639         0.521155         0.497022         0.481764
#
#    d4_hero_winrate  r5_hero_winrate  d5_hero_winrate
# 0         0.514097         0.516562         0.473145
# 1         0.515557         0.470536         0.549747
# 2         0.492620         0.434292         0.493916
# 3         0.500539         0.510045         0.472703
# 4         0.469922         0.436076         0.479300
#
# [5 rows x 478 columns]

# %% [markdown]
# ---
# # Process fights

# %% [markdown]
# ### Process categorical features

# %% [markdown]
# *Replace NaN and Float to Int32*

# %%
for i in range(1,6):
    for team in ["r", "d"]:
        for feature in ["hero_id"]:
            fights["%s%s_%s" % (team, i, feature)] = fights["%s%s_%s" % (team, i, feature)].fillna(200)
            fights["%s%s_%s" % (team, i, feature)] = fights["%s%s_%s" % (team, i, feature)].astype("uint8")

# %% [markdown]
# ---
# *Dummy encode **heroes** *

# %%
heroes_unique_values = pd.concat([fights["r%s_hero_id"%i] for i in range(1,6)] \
                                 + [fights["d%s_hero_id"%i] for i in range(1,6)]).unique()

heroes_unique_values = sorted(heroes_unique_values)
dummy_heroes_column_names = ["hero_%s"%i for i in heroes_unique_values]

dummy_heroes_shape = (fights.shape[0], len(heroes_unique_values))
dummy_heroes = pd.DataFrame(np.zeros(dummy_heroes_shape), columns=dummy_heroes_column_names).astype("uint8")

for feature in ["r%s_hero_id" % i for i in range(1,6)]:
    encoded_feature = pd.get_dummies(fights[feature], prefix="hero")
    dummy_heroes[encoded_feature.columns] += encoded_feature
    
for feature in ["d%s_hero_id" % i for i in range(1,6)]:
    encoded_feature = pd.get_dummies(fights[feature], prefix="hero")
    dummy_heroes[encoded_feature.columns] -= encoded_feature

# %%
fights = pd.concat([fights, dummy_heroes], axis=1)

# %%
for i in range(1,6):
    for team in ["r", "d"]:
        for feature in ["hero", "items", "role"]:
            CATEFORICAL_FEATURES.append("%s%s_%s" % (team, i, feature))

CATEFORICAL_FEATURES += dummy_heroes.columns.tolist()

# %% [markdown]
# ### Process numeric features

# %% [markdown]
# *Get player armor*

# %%
for team in ["r", "d"]:
    for i in range(1, 6):
        player = "%s%s" % (team, i)
        
        agiength = fights["%s_level" % player] * fights["%s_hero_agi_gain" % player] + fights["%s_hero_base_agi" % player]
        fights["%s_armor" % player] = fights["%s_hero_base_armor" % player] + agiength/6
        
        fights = fights.drop(["%s_hero_agi_gain" % player, "%s_hero_base_agi" % player, "%s_hero_base_armor" % player], axis=1)

# %% [markdown]
# *Get player damage*

# %%
for team in ["r", "d"]:
    for i in range(1, 6):
        player = "%s%s" % (team, i)
        
        fights["%s_attack" % player] = (fights["%s_hero_base_attack_min" % player] + fights["%s_hero_base_attack_max" % player])/2
        fights["%s_rated_attack" % player] = fights["%s_attack" % player] * fights["%s_hero_attack_rate" % player]
        fights["%s_ranged_rated_attack" % player] = fights["%s_rated_attack" % player] * fights["%s_hero_attack_range" % player]

# %% [markdown]
# *Calculate map features*

# %%
for team in ["r", "d"]:
    for i in range(1, 6):
        fights["%s%s_part_of_half_map" % (team, i)] =  - fights["%s%s_y" % (team, i)]
        
#         p1 = (fights["%s%s_x" % (team, i)]>120) & (fights["%s%s_y" % (team, i)]>120)
#         p2 = (fights["%s%s_x" % (team, i)]<=120) & (fights["%s%s_y" % (team, i)]>120)
#         p3 = (fights["%s%s_x" % (team, i)]>120) & (fights["%s%s_y" % (team, i)]<=120)
#         p4 = (fights["%s%s_x" % (team, i)]<=120) & (fights["%s%s_y" % (team, i)]<=120)
        
#         fights[p1]["%s%s_map_part" % (team, i)] = 1
#         fights[p2]["%s%s_map_part" % (team, i)] = 2
#         fights[p3]["%s%s_map_part" % (team, i)] = 3
#         fights[p4]["%s%s_map_part" % (team, i)] = 4

        fights = fights.drop(["%s%s_x" % (team, i), "%s%s_y" % (team, i)], axis=1)

# %% [markdown]
# *Convert players characteristics to team characteristics*

# %%
players_characteristics = set([i[3:] for i in (set(fights.columns) - set(CATEFORICAL_FEATURES)) \
                                       if (i[0]  == "d" and i[1].isnumeric())])

print(players_characteristics)
# Out:
# {'hero_int_gain', 'hero_base_mr', 'lh', 'deaths', 'health', 'hero_attack_rate', 'armor', 'hero_base_health_regen', 'stuns', 'obs_placed', 'hero_id', 'hero_projectile_speed', 'hero_turn_rate', 'hero_legs', 'hero_base_mana_regen', 'hero_move_speed', 'attack', 'denies', 'rune_pickups', 'hero_winrate', 'hero_str_gain', 'xp', 'hero_attack_range', 'part_of_half_map', 'hero_base_int', 'assists', 'kills', 'hero_base_health', 'firstblood_claimed', 'ranged_rated_attack', 'hero_base_attack_max', 'gold', 'creeps_stacked', 'hero_base_mana', 'towers_killed', 'hero_base_attack_min', 'camps_stacked', 'hero_base_str', 'roshans_killed', 'teamfight_participation', 'sen_placed', 'level', 'max_health', 'max_mana', 'rated_attack'}

# %%
for feature in tqdm_notebook(players_characteristics):
    for team in ["r", "d"]:
        team_name = {"r": "radiant","d": "dire"}
        
        team_values = fights[["%s%s_%s" % (team, i, feature) for i in range(1,6)]]
        
        fights["%s_%s_mean" % (team_name[team], feature)] = team_values.mean(axis=1).get_values()
        fights["%s_%s_median" % (team_name[team], feature)] = team_values.median(axis=1).get_values()
        fights["%s_%s_max" % (team_name[team], feature)] = team_values.max(axis=1).get_values()
        fights["%s_%s_min" % (team_name[team], feature)] = team_values.min(axis=1).get_values()
        
        fights = fights.drop(["%s%s_%s" % (team, i, feature) for i in range(1,6)], axis=1)

# %% [markdown]
# *Calculate polynom*

# %%
for team in ["radiant", "dire"]:
    player_features = ["%s_%s_mean" % (team, feature) for feature  in players_characteristics]
        
    poly = PolynomialFeatures(2)
    player_features_values = poly.fit_transform(fights[player_features].fillna(0))
    player_features_names = ["%s_feature_%s" % (team, j) for j in range(player_features_values.shape[1])]

    player_features_df = pd.DataFrame(player_features_values, columns=player_features_names)
    fights = pd.concat([fights, player_features_df], axis=1)

# %% [markdown]
# *Calculate delta*

# %%
team_characteristics = set([i.replace("radiant_", "") for i in (set(fights.columns) - set(CATEFORICAL_FEATURES)) \
                                       if (i.startswith("radiant"))])

# %%
for feature in tqdm_notebook(team_characteristics):
    dire = "dire_" + feature
    radiant = "radiant_" + feature
    
    
    fights[feature+"_delta"] = fights[radiant]-fights[dire]
    fights[feature+"_delta_2"] = (fights[radiant]-fights[dire])**2

# %%
fights.columns.tolist()
# Out:
# ['match_id_hash',
#  'game_time',
#  'game_mode',
#  'lobby_type',
#  'objectives_len',
#  'chat_len',
#  'is_train',
#  'fight_id',
#  'r1_hero_attack_type',
#  'd1_hero_attack_type',
#  'r2_hero_attack_type',
#  'd2_hero_attack_type',
#  'r3_hero_attack_type',
#  'd3_hero_attack_type',
#  'r4_hero_attack_type',
#  'd4_hero_attack_type',
#  'r5_hero_attack_type',
#  'd5_hero_attack_type',
#  'r1_hero_primary_attr',
#  'd1_hero_primary_attr',
#  'r2_hero_primary_attr',
#  'd2_hero_primary_attr',
#  'r3_hero_primary_attr',
#  'd3_hero_primary_attr',
#  'r4_hero_primary_attr',
#  'd4_hero_primary_attr',
#  'r5_hero_primary_attr',
#  'd5_hero_primary_attr',
#  'hero_1',
#  'hero_2',
#  'hero_3',
#  'hero_4',
#  'hero_5',
#  'hero_6',
#  'hero_7',
#  'hero_8',
#  'hero_9',
#  'hero_10',
#  'hero_11',
#  'hero_12',
#  'hero_13',
#  'hero_14',
#  'hero_15',
#  'hero_16',
#  'hero_17',
#  'hero_18',
#  'hero_19',
#  'hero_20',
#  'hero_21',
#  'hero_22',
#  'hero_23',
#  'hero_25',
#  'hero_26',
#  'hero_27',
#  'hero_28',
#  'hero_29',
#  'hero_30',
#  'hero_31',
#  'hero_32',
#  'hero_33',
#  'hero_34',
#  'hero_35',
#  'hero_36',
#  'hero_37',
#  'hero_38',
#  'hero_39',
#  'hero_40',
#  'hero_41',
#  'hero_42',
#  'hero_43',
#  'hero_44',
#  'hero_45',
#  'hero_46',
#  'hero_47',
#  'hero_48',
#  'hero_49',
#  'hero_50',
#  'hero_51',
#  'hero_52',
#  'hero_53',
#  'hero_54',
#  'hero_55',
#  'hero_56',
#  'hero_57',
#  'hero_58',
#  'hero_59',
#  'hero_60',
#  'hero_61',
#  'hero_62',
#  'hero_63',
#  'hero_64',
#  'hero_65',
#  'hero_66',
#  'hero_67',
#  'hero_68',
#  'hero_69',
#  'hero_70',
#  'hero_71',
#  'hero_72',
#  'hero_73',
#  'hero_74',
#  'hero_75',
#  'hero_76',
#  'hero_77',
#  'hero_78',
#  'hero_79',
#  'hero_80',
#  'hero_81',
#  'hero_82',
#  'hero_83',
#  'hero_84',
#  'hero_85',
#  'hero_86',
#  'hero_87',
#  'hero_88',
#  'hero_89',
#  'hero_90',
#  'hero_91',
#  'hero_92',
#  'hero_93',
#  'hero_94',
#  'hero_95',
#  'hero_96',
#  'hero_97',
#  'hero_98',
#  'hero_99',
#  'hero_100',
#  'hero_101',
#  'hero_102',
#  'hero_103',
#  'hero_104',
#  'hero_105',
#  'hero_106',
#  'hero_107',
#  'hero_108',
#  'hero_109',
#  'hero_110',
#  'hero_111',
#  'hero_112',
#  'hero_113',
#  'hero_114',
#  'hero_119',
#  'hero_120',
#  'radiant_hero_int_gain_mean',
#  'radiant_hero_int_gain_median',
#  'radiant_hero_int_gain_max',
#  'radiant_hero_int_gain_min',
#  'dire_hero_int_gain_mean',
#  'dire_hero_int_gain_median',
#  'dire_hero_int_gain_max',
#  'dire_hero_int_gain_min',
#  'radiant_hero_base_mr_mean',
#  'radiant_hero_base_mr_median',
#  'radiant_hero_base_mr_max',
#  'radiant_hero_base_mr_min',
#  'dire_hero_base_mr_mean',
#  'dire_hero_base_mr_median',
#  'dire_hero_base_mr_max',
#  'dire_hero_base_mr_min',
#  'radiant_lh_mean',
#  'radiant_lh_median',
#  'radiant_lh_max',
#  'radiant_lh_min',
#  'dire_lh_mean',
#  'dire_lh_median',
#  'dire_lh_max',
#  'dire_lh_min',
#  'radiant_deaths_mean',
#  'radiant_deaths_median',
#  'radiant_deaths_max',
#  'radiant_deaths_min',
#  'dire_deaths_mean',
#  'dire_deaths_median',
#  'dire_deaths_max',
#  'dire_deaths_min',
#  'radiant_health_mean',
#  'radiant_health_median',
#  'radiant_health_max',
#  'radiant_health_min',
#  'dire_health_mean',
#  'dire_health_median',
#  'dire_health_max',
#  'dire_health_min',
#  'radiant_hero_attack_rate_mean',
#  'radiant_hero_attack_rate_median',
#  'radiant_hero_attack_rate_max',
#  'radiant_hero_attack_rate_min',
#  'dire_hero_attack_rate_mean',
#  'dire_hero_attack_rate_median',
#  'dire_hero_attack_rate_max',
#  'dire_hero_attack_rate_min',
#  'radiant_armor_mean',
#  'radiant_armor_median',
#  'radiant_armor_max',
#  'radiant_armor_min',
#  'dire_armor_mean',
#  'dire_armor_median',
#  'dire_armor_max',
#  'dire_armor_min',
#  'radiant_hero_base_health_regen_mean',
#  'radiant_hero_base_health_regen_median',
#  'radiant_hero_base_health_regen_max',
#  'radiant_hero_base_health_regen_min',
#  'dire_hero_base_health_regen_mean',
#  'dire_hero_base_health_regen_median',
#  'dire_hero_base_health_regen_max',
#  'dire_hero_base_health_regen_min',
#  'radiant_stuns_mean',
#  'radiant_stuns_median',
#  'radiant_stuns_max',
#  'radiant_stuns_min',
#  'dire_stuns_mean',
#  'dire_stuns_median',
#  'dire_stuns_max',
#  'dire_stuns_min',
#  'radiant_obs_placed_mean',
#  'radiant_obs_placed_median',
#  'radiant_obs_placed_max',
#  'radiant_obs_placed_min',
#  'dire_obs_placed_mean',
#  'dire_obs_placed_median',
#  'dire_obs_placed_max',
#  'dire_obs_placed_min',
#  'radiant_hero_id_mean',
#  'radiant_hero_id_median',
#  'radiant_hero_id_max',
#  'radiant_hero_id_min',
#  'dire_hero_id_mean',
#  'dire_hero_id_median',
#  'dire_hero_id_max',
#  'dire_hero_id_min',
#  'radiant_hero_projectile_speed_mean',
#  'radiant_hero_projectile_speed_median',
#  'radiant_hero_projectile_speed_max',
#  'radiant_hero_projectile_speed_min',
#  'dire_hero_projectile_speed_mean',
#  'dire_hero_projectile_speed_median',
#  'dire_hero_projectile_speed_max',
#  'dire_hero_projectile_speed_min',
#  'radiant_hero_turn_rate_mean',
#  'radiant_hero_turn_rate_median',
#  'radiant_hero_turn_rate_max',
#  'radiant_hero_turn_rate_min',
#  'dire_hero_turn_rate_mean',
#  'dire_hero_turn_rate_median',
#  'dire_hero_turn_rate_max',
#  'dire_hero_turn_rate_min',
#  'radiant_hero_legs_mean',
#  'radiant_hero_legs_median',
#  'radiant_hero_legs_max',
#  'radiant_hero_legs_min',
#  'dire_hero_legs_mean',
#  'dire_hero_legs_median',
#  'dire_hero_legs_max',
#  'dire_hero_legs_min',
#  'radiant_hero_base_mana_regen_mean',
#  'radiant_hero_base_mana_regen_median',
#  'radiant_hero_base_mana_regen_max',
#  'radiant_hero_base_mana_regen_min',
#  'dire_hero_base_mana_regen_mean',
#  'dire_hero_base_mana_regen_median',
#  'dire_hero_base_mana_regen_max',
#  'dire_hero_base_mana_regen_min',
#  'radiant_hero_move_speed_mean',
#  'radiant_hero_move_speed_median',
#  'radiant_hero_move_speed_max',
#  'radiant_hero_move_speed_min',
#  'dire_hero_move_speed_mean',
#  'dire_hero_move_speed_median',
#  'dire_hero_move_speed_max',
#  'dire_hero_move_speed_min',
#  'radiant_attack_mean',
#  'radiant_attack_median',
#  'radiant_attack_max',
#  'radiant_attack_min',
#  'dire_attack_mean',
#  'dire_attack_median',
#  'dire_attack_max',
#  'dire_attack_min',
#  'radiant_denies_mean',
#  'radiant_denies_median',
#  'radiant_denies_max',
#  'radiant_denies_min',
#  'dire_denies_mean',
#  'dire_denies_median',
#  'dire_denies_max',
#  'dire_denies_min',
#  'radiant_rune_pickups_mean',
#  'radiant_rune_pickups_median',
#  'radiant_rune_pickups_max',
#  'radiant_rune_pickups_min',
#  'dire_rune_pickups_mean',
#  'dire_rune_pickups_median',
#  'dire_rune_pickups_max',
#  'dire_rune_pickups_min',
#  'radiant_hero_winrate_mean',
#  'radiant_hero_winrate_median',
#  'radiant_hero_winrate_max',
#  'radiant_hero_winrate_min',
#  'dire_hero_winrate_mean',
#  'dire_hero_winrate_median',
#  'dire_hero_winrate_max',
#  'dire_hero_winrate_min',
#  'radiant_hero_str_gain_mean',
#  'radiant_hero_str_gain_median',
#  'radiant_hero_str_gain_max',
#  'radiant_hero_str_gain_min',
#  'dire_hero_str_gain_mean',
#  'dire_hero_str_gain_median',
#  'dire_hero_str_gain_max',
#  'dire_hero_str_gain_min',
#  'radiant_xp_mean',
#  'radiant_xp_median',
#  'radiant_xp_max',
#  'radiant_xp_min',
#  'dire_xp_mean',
#  'dire_xp_median',
#  'dire_xp_max',
#  'dire_xp_min',
#  'radiant_hero_attack_range_mean',
#  'radiant_hero_attack_range_median',
#  'radiant_hero_attack_range_max',
#  'radiant_hero_attack_range_min',
#  'dire_hero_attack_range_mean',
#  'dire_hero_attack_range_median',
#  'dire_hero_attack_range_max',
#  'dire_hero_attack_range_min',
#  'radiant_part_of_half_map_mean',
#  'radiant_part_of_half_map_median',
#  'radiant_part_of_half_map_max',
#  'radiant_part_of_half_map_min',
#  'dire_part_of_half_map_mean',
#  'dire_part_of_half_map_median',
#  'dire_part_of_half_map_max',
#  'dire_part_of_half_map_min',
#  'radiant_hero_base_int_mean',
#  'radiant_hero_base_int_median',
#  'radiant_hero_base_int_max',
#  'radiant_hero_base_int_min',
#  'dire_hero_base_int_mean',
#  'dire_hero_base_int_median',
#  'dire_hero_base_int_max',
#  'dire_hero_base_int_min',
#  'radiant_assists_mean',
#  'radiant_assists_median',
#  'radiant_assists_max',
#  'radiant_assists_min',
#  'dire_assists_mean',
#  'dire_assists_median',
#  'dire_assists_max',
#  'dire_assists_min',
#  'radiant_kills_mean',
#  'radiant_kills_median',
#  'radiant_kills_max',
#  'radiant_kills_min',
#  'dire_kills_mean',
#  'dire_kills_median',
#  'dire_kills_max',
#  'dire_kills_min',
#  'radiant_hero_base_health_mean',
#  'radiant_hero_base_health_median',
#  'radiant_hero_base_health_max',
#  'radiant_hero_base_health_min',
#  'dire_hero_base_health_mean',
#  'dire_hero_base_health_median',
#  'dire_hero_base_health_max',
#  'dire_hero_base_health_min',
#  'radiant_firstblood_claimed_mean',
#  'radiant_firstblood_claimed_median',
#  'radiant_firstblood_claimed_max',
#  'radiant_firstblood_claimed_min',
#  'dire_firstblood_claimed_mean',
#  'dire_firstblood_claimed_median',
#  'dire_firstblood_claimed_max',
#  'dire_firstblood_claimed_min',
#  'radiant_ranged_rated_attack_mean',
#  'radiant_ranged_rated_attack_median',
#  'radiant_ranged_rated_attack_max',
#  'radiant_ranged_rated_attack_min',
#  'dire_ranged_rated_attack_mean',
#  'dire_ranged_rated_attack_median',
#  'dire_ranged_rated_attack_max',
#  'dire_ranged_rated_attack_min',
#  'radiant_hero_base_attack_max_mean',
#  'radiant_hero_base_attack_max_median',
#  'radiant_hero_base_attack_max_max',
#  'radiant_hero_base_attack_max_min',
#  'dire_hero_base_attack_max_mean',
#  'dire_hero_base_attack_max_median',
#  'dire_hero_base_attack_max_max',
#  'dire_hero_base_attack_max_min',
#  'radiant_gold_mean',
#  'radiant_gold_median',
#  'radiant_gold_max',
#  'radiant_gold_min',
#  'dire_gold_mean',
#  'dire_gold_median',
#  'dire_gold_max',
#  'dire_gold_min',
#  'radiant_creeps_stacked_mean',
#  'radiant_creeps_stacked_median',
#  'radiant_creeps_stacked_max',
#  'radiant_creeps_stacked_min',
#  'dire_creeps_stacked_mean',
#  'dire_creeps_stacked_median',
#  'dire_creeps_stacked_max',
#  'dire_creeps_stacked_min',
#  'radiant_hero_base_mana_mean',
#  'radiant_hero_base_mana_median',
#  'radiant_hero_base_mana_max',
#  'radiant_hero_base_mana_min',
#  'dire_hero_base_mana_mean',
#  'dire_hero_base_mana_median',
#  'dire_hero_base_mana_max',
#  'dire_hero_base_mana_min',
#  'radiant_towers_killed_mean',
#  'radiant_towers_killed_median',
#  'radiant_towers_killed_max',
#  'radiant_towers_killed_min',
#  'dire_towers_killed_mean',
#  'dire_towers_killed_median',
#  'dire_towers_killed_max',
#  'dire_towers_killed_min',
#  'radiant_hero_base_attack_min_mean',
#  'radiant_hero_base_attack_min_median',
#  'radiant_hero_base_attack_min_max',
#  'radiant_hero_base_attack_min_min',
#  'dire_hero_base_attack_min_mean',
#  'dire_hero_base_attack_min_median',
#  'dire_hero_base_attack_min_max',
#  'dire_hero_base_attack_min_min',
#  'radiant_camps_stacked_mean',
#  'radiant_camps_stacked_median',
#  'radiant_camps_stacked_max',
#  'radiant_camps_stacked_min',
#  'dire_camps_stacked_mean',
#  'dire_camps_stacked_median',
#  'dire_camps_stacked_max',
#  'dire_camps_stacked_min',
#  'radiant_hero_base_str_mean',
#  'radiant_hero_base_str_median',
#  'radiant_hero_base_str_max',
#  'radiant_hero_base_str_min',
#  'dire_hero_base_str_mean',
#  'dire_hero_base_str_median',
#  'dire_hero_base_str_max',
#  'dire_hero_base_str_min',
#  'radiant_roshans_killed_mean',
#  'radiant_roshans_killed_median',
#  'radiant_roshans_killed_max',
#  'radiant_roshans_killed_min',
#  'dire_roshans_killed_mean',
#  'dire_roshans_killed_median',
#  'dire_roshans_killed_max',
#  'dire_roshans_killed_min',
#  'radiant_teamfight_participation_mean',
#  'radiant_teamfight_participation_median',
#  'radiant_teamfight_participation_max',
#  'radiant_teamfight_participation_min',
#  'dire_teamfight_participation_mean',
#  'dire_teamfight_participation_median',
#  'dire_teamfight_participation_max',
#  'dire_teamfight_participation_min',
#  'radiant_sen_placed_mean',
#  'radiant_sen_placed_median',
#  'radiant_sen_placed_max',
#  'radiant_sen_placed_min',
#  'dire_sen_placed_mean',
#  'dire_sen_placed_median',
#  'dire_sen_placed_max',
#  'dire_sen_placed_min',
#  'radiant_level_mean',
#  'radiant_level_median',
#  'radiant_level_max',
#  'radiant_level_min',
#  'dire_level_mean',
#  'dire_level_median',
#  'dire_level_max',
#  'dire_level_min',
#  'radiant_max_health_mean',
#  'radiant_max_health_median',
#  'radiant_max_health_max',
#  'radiant_max_health_min',
#  'dire_max_health_mean',
#  'dire_max_health_median',
#  'dire_max_health_max',
#  'dire_max_health_min',
#  'radiant_max_mana_mean',
#  'radiant_max_mana_median',
#  'radiant_max_mana_max',
#  'radiant_max_mana_min',
#  'dire_max_mana_mean',
#  'dire_max_mana_median',
#  'dire_max_mana_max',
#  'dire_max_mana_min',
#  'radiant_rated_attack_mean',
#  'radiant_rated_attack_median',
#  'radiant_rated_attack_max',
#  'radiant_rated_attack_min',
#  'dire_rated_attack_mean',
#  'dire_rated_attack_median',
#  'dire_rated_attack_max',
#  'dire_rated_attack_min',
#  'radiant_feature_0',
#  'radiant_feature_1',
#  'radiant_feature_2',
#  'radiant_feature_3',
#  'radiant_feature_4',
#  'radiant_feature_5',
#  'radiant_feature_6',
#  'radiant_feature_7',
#  'radiant_feature_8',
#  'radiant_feature_9',
#  'radiant_feature_10',
#  'radiant_feature_11',
#  'radiant_feature_12',
#  'radiant_feature_13',
#  'radiant_feature_14',
#  'radiant_feature_483',
#  'radiant_feature_484',
#  'radiant_feature_485',
#  'radiant_feature_486',
#  'radiant_feature_487',
#  'radiant_feature_488',
#  'radiant_feature_489',
#  'radiant_feature_490',
#  'radiant_feature_491',
#  'radiant_feature_492',
#  'radiant_feature_493',
#  'radiant_feature_494',
#  'radiant_feature_495',
#  'radiant_feature_496',
#  ...]

# %% [markdown]
# *Distance metrci featues*

# %%
annoy_features = [i + "_delta" for i in team_characteristics]
annoy_data = fights[fights["is_train"] == True][annoy_features]
annoy_index = fights[fights["is_train"] == True].index.get_values()

# %%
annoy_vector_size = len(annoy_features)
annoy = AnnoyIndex(annoy_vector_size)

# %%
for vec, i in zip(annoy_data.get_values(), annoy_index):
    annoy.add_item(i, vec)

# %%
annoy.build(10)
# Out:
# True

# %%
k = 0

def get_nn_info(row):
    global k
    
    if k%1000==0: print(k)
    k+=1
    
    vec = row[annoy_features].get_values()
    indexes = annoy.get_nns_by_vector(vec, 21)
    
    if row.fight_id in indexes:
        indexes.remove(row.fight_id)
    else:
        indexes = indexes[:-1] 
    
    ys = target["radiant_win"].astype("int").get_values()[indexes]
    
    info = {
        "nn_mean_5": np.mean(ys[:5]),
        "nn_median_5": np.median(ys[:5]),
        "nn_mean_10": np.mean(ys[:10]),
        "nn_median_10": np.median(ys[:10]),
        "nn_mean_20": np.mean(ys),
        "nn_median_20": np.median(ys)
    }
    return pd.Series(info)

# %%
fights = pd.concat([fights, fights.apply(get_nn_info, axis="columns")], axis=1)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000

# %% [markdown]
# # Train/Validate/Test split

# %%
fights = fights.fillna(0)

# %%
fights.shape
# Out:
# (49675, 5193)

# %%
test_data = fights[fights["is_train"] == False]
test_data = test_data.drop(["fight_id", "is_train"], axis=1)

train_data = fights[fights["is_train"] == True]
train_data = train_data.drop(["fight_id", "is_train"], axis=1)

# %%
train_data.shape
# Out:
# (39675, 5191)

# %%
validation_size = 0.3
validation_split = int(train_data.shape[0]*validation_size)

# %%
validation_data = train_data.loc[:validation_split]
train_data = train_data.loc[validation_split:]

# %%
target_validate = target.loc[:validation_split]
target_train = target.loc[validation_split:]

# %%
train_data.to_csv("processed_dataset/train.csv")
target_train.to_csv("processed_dataset/target_train.csv")

# %%
test_data.to_csv("processed_dataset/test.csv")

# %%
n_batches = 3

for batch in range(1, n_batches+1):
    print("BATCH #%s" % batch)
    l = int(train_data.shape[0]*(batch-1)/n_batches)
    r = int(train_data.shape[0]*(batch)/n_batches)
    
    train_batch = train_data.loc[l:r]
    target_batch = target_train.loc[l:r]
    
    train_batch.to_csv("processed_dataset/train_%s.csv" % batch)
    target_batch.to_csv("processed_dataset/target_train_%s.csv" % batch)

# %%
validation_data.to_csv("processed_dataset/validation.csv")
target_validate.to_csv("processed_dataset/target_validate.csv")

# %%
with open("processed_dataset/categorical_features.json", "w") as f:
    f.write(json.dumps(CATEFORICAL_FEATURES))

# %%
print("hello")
# Out:
# hello

# %%
train_data.shape
# Out:
# (0, 5191)

# %%
fights.shape
# Out:
# (49675, 5193)
